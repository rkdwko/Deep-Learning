# %% [markdown]
# # 베스트 모델 만들기 - 와인 사례
# ## 이진 분류
# ## 베스트 모델 업데이트하기

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
# 데이터 입력
df_pre = pd.read_csv('D:/Workspace/Deep-Learning/dataset/wine.csv', header=None)
df = df_pre.sample(frac=1)
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
# 모델 설정
model = Sequential() 
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0813 11:55:06.946735  5168 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0813 11:55:06.946735  5168 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0813 11:55:06.962335  5168 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
# 모델 컴파일 
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# W0813 11:55:11.595363  5168 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0813 11:55:11.631964  5168 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0813 11:55:11.636964  5168 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# 모델 저장 폴더 설정
import os
MODEL_DIR = './model2/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

# %%
# 모델 저장 조건 설정
modelpath="./model2/{epoch:02d}-{val_loss:.4f}.hdf5"

# checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1)
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)

# %%
# 모델 실행 및 저장
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, 
          verbose=0, callbacks=[checkpointer])
# Out:
# W0813 11:55:26.494641  5168 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 00001: val_loss improved from inf to 0.31023, saving model to ./model2/01-0.3102.hdf5
#
# Epoch 00002: val_loss improved from 0.31023 to 0.25229, saving model to ./model2/02-0.2523.hdf5
#
# Epoch 00003: val_loss improved from 0.25229 to 0.21336, saving model to ./model2/03-0.2134.hdf5
#
# Epoch 00004: val_loss improved from 0.21336 to 0.20451, saving model to ./model2/04-0.2045.hdf5
#
# Epoch 00005: val_loss improved from 0.20451 to 0.19734, saving model to ./model2/05-0.1973.hdf5
#
# Epoch 00006: val_loss improved from 0.19734 to 0.18679, saving model to ./model2/06-0.1868.hdf5
#
# Epoch 00007: val_loss improved from 0.18679 to 0.18067, saving model to ./model2/07-0.1807.hdf5
#
# Epoch 00008: val_loss improved from 0.18067 to 0.18017, saving model to ./model2/08-0.1802.hdf5
#
# Epoch 00009: val_loss improved from 0.18017 to 0.17978, saving model to ./model2/09-0.1798.hdf5
#
# Epoch 00010: val_loss improved from 0.17978 to 0.17670, saving model to ./model2/10-0.1767.hdf5
#
# Epoch 00011: val_loss improved from 0.17670 to 0.16681, saving model to ./model2/11-0.1668.hdf5
#
# Epoch 00012: val_loss improved from 0.16681 to 0.16343, saving model to ./model2/12-0.1634.hdf5
#
# Epoch 00013: val_loss did not improve from 0.16343
#
# Epoch 00014: val_loss improved from 0.16343 to 0.15825, saving model to ./model2/14-0.1583.hdf5
#
# Epoch 00015: val_loss improved from 0.15825 to 0.15696, saving model to ./model2/15-0.1570.hdf5
#
# Epoch 00016: val_loss improved from 0.15696 to 0.15140, saving model to ./model2/16-0.1514.hdf5
#
# Epoch 00017: val_loss improved from 0.15140 to 0.14844, saving model to ./model2/17-0.1484.hdf5
#
# Epoch 00018: val_loss improved from 0.14844 to 0.14635, saving model to ./model2/18-0.1464.hdf5
#
# Epoch 00019: val_loss improved from 0.14635 to 0.14360, saving model to ./model2/19-0.1436.hdf5
#
# Epoch 00020: val_loss did not improve from 0.14360
#
# Epoch 00021: val_loss improved from 0.14360 to 0.13690, saving model to ./model2/21-0.1369.hdf5
#
# Epoch 00022: val_loss improved from 0.13690 to 0.13400, saving model to ./model2/22-0.1340.hdf5
#
# Epoch 00023: val_loss did not improve from 0.13400
#
# Epoch 00024: val_loss improved from 0.13400 to 0.12855, saving model to ./model2/24-0.1285.hdf5
#
# Epoch 00025: val_loss improved from 0.12855 to 0.12651, saving model to ./model2/25-0.1265.hdf5
#
# Epoch 00026: val_loss improved from 0.12651 to 0.12274, saving model to ./model2/26-0.1227.hdf5
#
# Epoch 00027: val_loss improved from 0.12274 to 0.12139, saving model to ./model2/27-0.1214.hdf5
#
# Epoch 00028: val_loss improved from 0.12139 to 0.11769, saving model to ./model2/28-0.1177.hdf5
#
# Epoch 00029: val_loss did not improve from 0.11769
#
# Epoch 00030: val_loss improved from 0.11769 to 0.11301, saving model to ./model2/30-0.1130.hdf5
#
# Epoch 00031: val_loss did not improve from 0.11301
#
# Epoch 00032: val_loss improved from 0.11301 to 0.10906, saving model to ./model2/32-0.1091.hdf5
#
# Epoch 00033: val_loss improved from 0.10906 to 0.10282, saving model to ./model2/33-0.1028.hdf5
#
# Epoch 00034: val_loss did not improve from 0.10282
#
# Epoch 00035: val_loss did not improve from 0.10282
#
# Epoch 00036: val_loss improved from 0.10282 to 0.10243, saving model to ./model2/36-0.1024.hdf5
#
# Epoch 00037: val_loss improved from 0.10243 to 0.09339, saving model to ./model2/37-0.0934.hdf5
#
# Epoch 00038: val_loss improved from 0.09339 to 0.09086, saving model to ./model2/38-0.0909.hdf5
#
# Epoch 00039: val_loss improved from 0.09086 to 0.09075, saving model to ./model2/39-0.0908.hdf5
#
# Epoch 00040: val_loss did not improve from 0.09075
#
# Epoch 00041: val_loss did not improve from 0.09075
#
# Epoch 00042: val_loss improved from 0.09075 to 0.08561, saving model to ./model2/42-0.0856.hdf5
#
# Epoch 00043: val_loss improved from 0.08561 to 0.08554, saving model to ./model2/43-0.0855.hdf5
#
# Epoch 00044: val_loss improved from 0.08554 to 0.08454, saving model to ./model2/44-0.0845.hdf5
#
# Epoch 00045: val_loss improved from 0.08454 to 0.08411, saving model to ./model2/45-0.0841.hdf5
#
# Epoch 00046: val_loss improved from 0.08411 to 0.08158, saving model to ./model2/46-0.0816.hdf5
#
# Epoch 00047: val_loss improved from 0.08158 to 0.08013, saving model to ./model2/47-0.0801.hdf5
#
# Epoch 00048: val_loss did not improve from 0.08013
#
# Epoch 00049: val_loss did not improve from 0.08013
#
# Epoch 00050: val_loss improved from 0.08013 to 0.07795, saving model to ./model2/50-0.0779.hdf5
#
# Epoch 00051: val_loss improved from 0.07795 to 0.07731, saving model to ./model2/51-0.0773.hdf5
#
# Epoch 00052: val_loss improved from 0.07731 to 0.07671, saving model to ./model2/52-0.0767.hdf5
#
# Epoch 00053: val_loss did not improve from 0.07671
#
# Epoch 00054: val_loss did not improve from 0.07671
#
# Epoch 00055: val_loss did not improve from 0.07671
#
# Epoch 00056: val_loss did not improve from 0.07671
#
# Epoch 00057: val_loss improved from 0.07671 to 0.07358, saving model to ./model2/57-0.0736.hdf5
#
# Epoch 00058: val_loss improved from 0.07358 to 0.07320, saving model to ./model2/58-0.0732.hdf5
#
# Epoch 00059: val_loss improved from 0.07320 to 0.07164, saving model to ./model2/59-0.0716.hdf5
#
# Epoch 00060: val_loss improved from 0.07164 to 0.07106, saving model to ./model2/60-0.0711.hdf5
#
# Epoch 00061: val_loss improved from 0.07106 to 0.07021, saving model to ./model2/61-0.0702.hdf5
#
# Epoch 00062: val_loss improved from 0.07021 to 0.06970, saving model to ./model2/62-0.0697.hdf5
#
# Epoch 00063: val_loss improved from 0.06970 to 0.06689, saving model to ./model2/63-0.0669.hdf5
#
# Epoch 00064: val_loss did not improve from 0.06689
#
# Epoch 00065: val_loss did not improve from 0.06689
#
# Epoch 00066: val_loss improved from 0.06689 to 0.06490, saving model to ./model2/66-0.0649.hdf5
#
# Epoch 00067: val_loss did not improve from 0.06490
#
# Epoch 00068: val_loss did not improve from 0.06490
#
# Epoch 00069: val_loss did not improve from 0.06490
#
# Epoch 00070: val_loss improved from 0.06490 to 0.06322, saving model to ./model2/70-0.0632.hdf5
#
# Epoch 00071: val_loss improved from 0.06322 to 0.06309, saving model to ./model2/71-0.0631.hdf5
#
# Epoch 00072: val_loss improved from 0.06309 to 0.06186, saving model to ./model2/72-0.0619.hdf5
#
# Epoch 00073: val_loss did not improve from 0.06186
#
# Epoch 00074: val_loss did not improve from 0.06186
#
# Epoch 00075: val_loss improved from 0.06186 to 0.06178, saving model to ./model2/75-0.0618.hdf5
#
# Epoch 00076: val_loss did not improve from 0.06178
#
# Epoch 00077: val_loss improved from 0.06178 to 0.05973, saving model to ./model2/77-0.0597.hdf5
#
# Epoch 00078: val_loss did not improve from 0.05973
#
# Epoch 00079: val_loss did not improve from 0.05973
#
# Epoch 00080: val_loss did not improve from 0.05973
#
# Epoch 00081: val_loss did not improve from 0.05973
#
# Epoch 00082: val_loss did not improve from 0.05973
#
# Epoch 00083: val_loss did not improve from 0.05973
#
# Epoch 00084: val_loss did not improve from 0.05973
#
# Epoch 00085: val_loss improved from 0.05973 to 0.05970, saving model to ./model2/85-0.0597.hdf5
#
# Epoch 00086: val_loss improved from 0.05970 to 0.05773, saving model to ./model2/86-0.0577.hdf5
#
# Epoch 00087: val_loss improved from 0.05773 to 0.05671, saving model to ./model2/87-0.0567.hdf5
#
# Epoch 00088: val_loss improved from 0.05671 to 0.05649, saving model to ./model2/88-0.0565.hdf5
#
# Epoch 00089: val_loss did not improve from 0.05649
#
# Epoch 00090: val_loss did not improve from 0.05649
#
# Epoch 00091: val_loss improved from 0.05649 to 0.05524, saving model to ./model2/91-0.0552.hdf5
#
# Epoch 00092: val_loss improved from 0.05524 to 0.05520, saving model to ./model2/92-0.0552.hdf5
#
# Epoch 00093: val_loss did not improve from 0.05520
#
# Epoch 00094: val_loss did not improve from 0.05520
#
# Epoch 00095: val_loss did not improve from 0.05520
#
# Epoch 00096: val_loss did not improve from 0.05520
#
# Epoch 00097: val_loss improved from 0.05520 to 0.05385, saving model to ./model2/97-0.0538.hdf5
#
# Epoch 00098: val_loss improved from 0.05385 to 0.05331, saving model to ./model2/98-0.0533.hdf5
#
# Epoch 00099: val_loss did not improve from 0.05331
#
# Epoch 00100: val_loss did not improve from 0.05331
#
# Epoch 00101: val_loss did not improve from 0.05331
#
# Epoch 00102: val_loss did not improve from 0.05331
#
# Epoch 00103: val_loss did not improve from 0.05331
#
# Epoch 00104: val_loss did not improve from 0.05331
#
# Epoch 00105: val_loss did not improve from 0.05331
#
# Epoch 00106: val_loss did not improve from 0.05331
#
# Epoch 00107: val_loss did not improve from 0.05331
#
# Epoch 00108: val_loss did not improve from 0.05331
#
# Epoch 00109: val_loss did not improve from 0.05331
#
# Epoch 00110: val_loss did not improve from 0.05331
#
# Epoch 00111: val_loss did not improve from 0.05331
# Epoch 00112: val_loss did not improve from 0.05331
#
# Epoch 00113: val_loss improved from 0.05331 to 0.05214, saving model to ./model2/113-0.0521.hdf5
#
# Epoch 00114: val_loss did not improve from 0.05214
#
# Epoch 00115: val_loss did not improve from 0.05214
#
# Epoch 00116: val_loss did not improve from 0.05214
#
# Epoch 00117: val_loss did not improve from 0.05214
#
# Epoch 00118: val_loss did not improve from 0.05214
#
# Epoch 00119: val_loss did not improve from 0.05214
#
# Epoch 00120: val_loss did not improve from 0.05214
#
# Epoch 00121: val_loss improved from 0.05214 to 0.05162, saving model to ./model2/121-0.0516.hdf5
#
# Epoch 00122: val_loss did not improve from 0.05162
#
# Epoch 00123: val_loss improved from 0.05162 to 0.05081, saving model to ./model2/123-0.0508.hdf5
#
# Epoch 00124: val_loss did not improve from 0.05081
#
# Epoch 00125: val_loss did not improve from 0.05081
#
# Epoch 00126: val_loss did not improve from 0.05081
#
# Epoch 00127: val_loss did not improve from 0.05081
#
# Epoch 00128: val_loss did not improve from 0.05081
#
# Epoch 00129: val_loss did not improve from 0.05081
#
# Epoch 00130: val_loss did not improve from 0.05081
#
# Epoch 00131: val_loss did not improve from 0.05081
#
# Epoch 00132: val_loss did not improve from 0.05081
#
# Epoch 00133: val_loss did not improve from 0.05081
#
# Epoch 00134: val_loss did not improve from 0.05081
#
# Epoch 00135: val_loss did not improve from 0.05081
#
# Epoch 00136: val_loss did not improve from 0.05081
#
# Epoch 00137: val_loss did not improve from 0.05081
#
# Epoch 00138: val_loss improved from 0.05081 to 0.04952, saving model to ./model2/138-0.0495.hdf5
#
# Epoch 00139: val_loss did not improve from 0.04952
#
# Epoch 00140: val_loss did not improve from 0.04952
#
# Epoch 00141: val_loss did not improve from 0.04952
#
# Epoch 00142: val_loss did not improve from 0.04952
#
# Epoch 00143: val_loss did not improve from 0.04952
#
# Epoch 00144: val_loss did not improve from 0.04952
#
# Epoch 00145: val_loss did not improve from 0.04952
#
# Epoch 00146: val_loss did not improve from 0.04952
#
# Epoch 00147: val_loss did not improve from 0.04952
#
# Epoch 00148: val_loss did not improve from 0.04952
#
# Epoch 00149: val_loss did not improve from 0.04952
#
# Epoch 00150: val_loss did not improve from 0.04952
#
# Epoch 00151: val_loss did not improve from 0.04952
#
# Epoch 00152: val_loss did not improve from 0.04952
#
# Epoch 00153: val_loss did not improve from 0.04952
#
# Epoch 00154: val_loss did not improve from 0.04952
#
# Epoch 00155: val_loss did not improve from 0.04952
#
# Epoch 00156: val_loss did not improve from 0.04952
#
# Epoch 00157: val_loss did not improve from 0.04952
#
# Epoch 00158: val_loss did not improve from 0.04952
#
# Epoch 00159: val_loss did not improve from 0.04952
#
# Epoch 00160: val_loss did not improve from 0.04952
#
# Epoch 00161: val_loss did not improve from 0.04952
#
# Epoch 00162: val_loss did not improve from 0.04952
#
# Epoch 00163: val_loss did not improve from 0.04952
#
# Epoch 00164: val_loss improved from 0.04952 to 0.04947, saving model to ./model2/164-0.0495.hdf5
#
# Epoch 00165: val_loss did not improve from 0.04947
#
# Epoch 00166: val_loss improved from 0.04947 to 0.04837, saving model to ./model2/166-0.0484.hdf5
#
# Epoch 00167: val_loss did not improve from 0.04837
#
# Epoch 00168: val_loss did not improve from 0.04837
#
# Epoch 00169: val_loss did not improve from 0.04837
#
# Epoch 00170: val_loss did not improve from 0.04837
#
# Epoch 00171: val_loss did not improve from 0.04837
#
# Epoch 00172: val_loss improved from 0.04837 to 0.04834, saving model to ./model2/172-0.0483.hdf5
#
# Epoch 00173: val_loss did not improve from 0.04834
#
# Epoch 00174: val_loss did not improve from 0.04834
#
# Epoch 00175: val_loss did not improve from 0.04834
#
# Epoch 00176: val_loss did not improve from 0.04834
#
# Epoch 00177: val_loss did not improve from 0.04834
#
# Epoch 00178: val_loss did not improve from 0.04834
#
# Epoch 00179: val_loss did not improve from 0.04834
#
# Epoch 00180: val_loss did not improve from 0.04834
#
# Epoch 00181: val_loss did not improve from 0.04834
#
# Epoch 00182: val_loss did not improve from 0.04834
#
# Epoch 00183: val_loss did not improve from 0.04834
#
# Epoch 00184: val_loss did not improve from 0.04834
#
# Epoch 00185: val_loss did not improve from 0.04834
#
# Epoch 00186: val_loss did not improve from 0.04834
#
# Epoch 00187: val_loss improved from 0.04834 to 0.04707, saving model to ./model2/187-0.0471.hdf5
#
# Epoch 00188: val_loss did not improve from 0.04707
#
# Epoch 00189: val_loss did not improve from 0.04707
#
# Epoch 00190: val_loss did not improve from 0.04707
#
# Epoch 00191: val_loss did not improve from 0.04707
#
# Epoch 00192: val_loss did not improve from 0.04707
#
# Epoch 00193: val_loss did not improve from 0.04707
#
# Epoch 00194: val_loss did not improve from 0.04707
#
# Epoch 00195: val_loss did not improve from 0.04707
#
# Epoch 00196: val_loss did not improve from 0.04707
#
# Epoch 00197: val_loss did not improve from 0.04707
#
# Epoch 00198: val_loss did not improve from 0.04707
#
# Epoch 00199: val_loss did not improve from 0.04707
#
# Epoch 00200: val_loss did not improve from 0.04707
