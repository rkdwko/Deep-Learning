# %% [markdown]
# # 베스트 모델 만들기 - 와인 사례
# ## 이진 분류
# ## 베스트 모델 업데이트하기 - 자동 중단

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
# 데이터 입력
df_pre = pd.read_csv('../dataset/wine.csv', header=None)
df = df_pre.sample(frac=0.15)
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
# 모델 설정
model = Sequential() 
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0813 12:03:02.569360  7300 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0813 12:03:02.574361  7300 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0813 12:03:02.578361  7300 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
# 모델 컴파일 
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# W0813 12:03:07.463795  7300 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0813 12:03:07.496396  7300 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0813 12:03:07.501397  7300 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
import os
# 모델 저장 폴더 만들기
MODEL_DIR = './model4/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

modelpath="./model4/{epoch:02d}-{val_loss:.4f}.hdf5"

# %%
# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)

# %%
# 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

# %%
# 모델 실행
model.fit(X, Y, validation_split=0.2, epochs=3500, batch_size=500, verbose=0, 
          callbacks=[early_stopping_callback, checkpointer])
# Out:
# W0813 12:03:38.697787  7300 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 00001: val_loss improved from inf to 0.48569, saving model to ./model4/01-0.4857.hdf5
#
# Epoch 00002: val_loss improved from 0.48569 to 0.46145, saving model to ./model4/02-0.4614.hdf5
#
# Epoch 00003: val_loss improved from 0.46145 to 0.43585, saving model to ./model4/03-0.4359.hdf5
#
# Epoch 00004: val_loss improved from 0.43585 to 0.42138, saving model to ./model4/04-0.4214.hdf5
#
# Epoch 00005: val_loss improved from 0.42138 to 0.40821, saving model to ./model4/05-0.4082.hdf5
#
# Epoch 00006: val_loss improved from 0.40821 to 0.39492, saving model to ./model4/06-0.3949.hdf5
#
# Epoch 00007: val_loss improved from 0.39492 to 0.38671, saving model to ./model4/07-0.3867.hdf5
#
# Epoch 00008: val_loss improved from 0.38671 to 0.37956, saving model to ./model4/08-0.3796.hdf5
#
# Epoch 00009: val_loss improved from 0.37956 to 0.37288, saving model to ./model4/09-0.3729.hdf5
#
# Epoch 00010: val_loss improved from 0.37288 to 0.36592, saving model to ./model4/10-0.3659.hdf5
#
# Epoch 00011: val_loss improved from 0.36592 to 0.35985, saving model to ./model4/11-0.3598.hdf5
#
# Epoch 00012: val_loss improved from 0.35985 to 0.35466, saving model to ./model4/12-0.3547.hdf5
#
# Epoch 00013: val_loss improved from 0.35466 to 0.34982, saving model to ./model4/13-0.3498.hdf5
#
# Epoch 00014: val_loss improved from 0.34982 to 0.34476, saving model to ./model4/14-0.3448.hdf5
#
# Epoch 00015: val_loss improved from 0.34476 to 0.33875, saving model to ./model4/15-0.3388.hdf5
#
# Epoch 00016: val_loss improved from 0.33875 to 0.33340, saving model to ./model4/16-0.3334.hdf5
#
# Epoch 00017: val_loss improved from 0.33340 to 0.32870, saving model to ./model4/17-0.3287.hdf5
#
# Epoch 00018: val_loss improved from 0.32870 to 0.32503, saving model to ./model4/18-0.3250.hdf5
#
# Epoch 00019: val_loss improved from 0.32503 to 0.32351, saving model to ./model4/19-0.3235.hdf5
#
# Epoch 00020: val_loss improved from 0.32351 to 0.31945, saving model to ./model4/20-0.3194.hdf5
#
# Epoch 00021: val_loss improved from 0.31945 to 0.31214, saving model to ./model4/21-0.3121.hdf5
#
# Epoch 00022: val_loss improved from 0.31214 to 0.30754, saving model to ./model4/22-0.3075.hdf5
#
# Epoch 00023: val_loss improved from 0.30754 to 0.30330, saving model to ./model4/23-0.3033.hdf5
#
# Epoch 00024: val_loss improved from 0.30330 to 0.30017, saving model to ./model4/24-0.3002.hdf5
#
# Epoch 00025: val_loss improved from 0.30017 to 0.29819, saving model to ./model4/25-0.2982.hdf5
#
# Epoch 00026: val_loss improved from 0.29819 to 0.29324, saving model to ./model4/26-0.2932.hdf5
#
# Epoch 00027: val_loss improved from 0.29324 to 0.28743, saving model to ./model4/27-0.2874.hdf5
#
# Epoch 00028: val_loss improved from 0.28743 to 0.28356, saving model to ./model4/28-0.2836.hdf5
#
# Epoch 00029: val_loss improved from 0.28356 to 0.27899, saving model to ./model4/29-0.2790.hdf5
#
# Epoch 00030: val_loss improved from 0.27899 to 0.27641, saving model to ./model4/30-0.2764.hdf5
#
# Epoch 00031: val_loss improved from 0.27641 to 0.27229, saving model to ./model4/31-0.2723.hdf5
#
# Epoch 00032: val_loss improved from 0.27229 to 0.26734, saving model to ./model4/32-0.2673.hdf5
#
# Epoch 00033: val_loss improved from 0.26734 to 0.26371, saving model to ./model4/33-0.2637.hdf5
#
# Epoch 00034: val_loss improved from 0.26371 to 0.26031, saving model to ./model4/34-0.2603.hdf5
#
# Epoch 00035: val_loss improved from 0.26031 to 0.25867, saving model to ./model4/35-0.2587.hdf5
#
# Epoch 00036: val_loss improved from 0.25867 to 0.25552, saving model to ./model4/36-0.2555.hdf5
#
# Epoch 00037: val_loss improved from 0.25552 to 0.25222, saving model to ./model4/37-0.2522.hdf5
#
# Epoch 00038: val_loss improved from 0.25222 to 0.24963, saving model to ./model4/38-0.2496.hdf5
#
# Epoch 00039: val_loss improved from 0.24963 to 0.24747, saving model to ./model4/39-0.2475.hdf5
#
# Epoch 00040: val_loss improved from 0.24747 to 0.24554, saving model to ./model4/40-0.2455.hdf5
#
# Epoch 00041: val_loss improved from 0.24554 to 0.24458, saving model to ./model4/41-0.2446.hdf5
#
# Epoch 00042: val_loss improved from 0.24458 to 0.24238, saving model to ./model4/42-0.2424.hdf5
#
# Epoch 00043: val_loss improved from 0.24238 to 0.24051, saving model to ./model4/43-0.2405.hdf5
#
# Epoch 00044: val_loss improved from 0.24051 to 0.23852, saving model to ./model4/44-0.2385.hdf5
#
# Epoch 00045: val_loss improved from 0.23852 to 0.23779, saving model to ./model4/45-0.2378.hdf5
#
# Epoch 00046: val_loss improved from 0.23779 to 0.23761, saving model to ./model4/46-0.2376.hdf5
#
# Epoch 00047: val_loss improved from 0.23761 to 0.23509, saving model to ./model4/47-0.2351.hdf5
#
# Epoch 00048: val_loss improved from 0.23509 to 0.23232, saving model to ./model4/48-0.2323.hdf5
#
# Epoch 00049: val_loss improved from 0.23232 to 0.23067, saving model to ./model4/49-0.2307.hdf5
#
# Epoch 00050: val_loss improved from 0.23067 to 0.22986, saving model to ./model4/50-0.2299.hdf5
#
# Epoch 00051: val_loss improved from 0.22986 to 0.22804, saving model to ./model4/51-0.2280.hdf5
#
# Epoch 00052: val_loss improved from 0.22804 to 0.22678, saving model to ./model4/52-0.2268.hdf5
#
# Epoch 00053: val_loss improved from 0.22678 to 0.22529, saving model to ./model4/53-0.2253.hdf5
#
# Epoch 00054: val_loss improved from 0.22529 to 0.22449, saving model to ./model4/54-0.2245.hdf5
#
# Epoch 00055: val_loss improved from 0.22449 to 0.22336, saving model to ./model4/55-0.2234.hdf5
#
# Epoch 00056: val_loss improved from 0.22336 to 0.22151, saving model to ./model4/56-0.2215.hdf5
#
# Epoch 00057: val_loss improved from 0.22151 to 0.22003, saving model to ./model4/57-0.2200.hdf5
#
# Epoch 00058: val_loss improved from 0.22003 to 0.21853, saving model to ./model4/58-0.2185.hdf5
#
# Epoch 00059: val_loss improved from 0.21853 to 0.21712, saving model to ./model4/59-0.2171.hdf5
#
# Epoch 00060: val_loss improved from 0.21712 to 0.21671, saving model to ./model4/60-0.2167.hdf5
#
# Epoch 00061: val_loss improved from 0.21671 to 0.21662, saving model to ./model4/61-0.2166.hdf5
#
# Epoch 00062: val_loss improved from 0.21662 to 0.21342, saving model to ./model4/62-0.2134.hdf5
#
# Epoch 00063: val_loss improved from 0.21342 to 0.21089, saving model to ./model4/63-0.2109.hdf5
#
# Epoch 00064: val_loss improved from 0.21089 to 0.20938, saving model to ./model4/64-0.2094.hdf5
#
# Epoch 00065: val_loss improved from 0.20938 to 0.20923, saving model to ./model4/65-0.2092.hdf5
#
# Epoch 00066: val_loss improved from 0.20923 to 0.20844, saving model to ./model4/66-0.2084.hdf5
#
# Epoch 00067: val_loss improved from 0.20844 to 0.20578, saving model to ./model4/67-0.2058.hdf5
#
# Epoch 00068: val_loss improved from 0.20578 to 0.20497, saving model to ./model4/68-0.2050.hdf5
#
# Epoch 00069: val_loss improved from 0.20497 to 0.20370, saving model to ./model4/69-0.2037.hdf5
#
# Epoch 00070: val_loss improved from 0.20370 to 0.20368, saving model to ./model4/70-0.2037.hdf5
#
# Epoch 00071: val_loss did not improve from 0.20368
#
# Epoch 00072: val_loss improved from 0.20368 to 0.20214, saving model to ./model4/72-0.2021.hdf5
#
# Epoch 00073: val_loss improved from 0.20214 to 0.19937, saving model to ./model4/73-0.1994.hdf5
#
# Epoch 00074: val_loss improved from 0.19937 to 0.19822, saving model to ./model4/74-0.1982.hdf5
#
# Epoch 00075: val_loss improved from 0.19822 to 0.19803, saving model to ./model4/75-0.1980.hdf5
#
# Epoch 00076: val_loss did not improve from 0.19803
#
# Epoch 00077: val_loss improved from 0.19803 to 0.19747, saving model to ./model4/77-0.1975.hdf5
#
# Epoch 00078: val_loss improved from 0.19747 to 0.19580, saving model to ./model4/78-0.1958.hdf5
#
# Epoch 00079: val_loss improved from 0.19580 to 0.19301, saving model to ./model4/79-0.1930.hdf5
#
# Epoch 00080: val_loss improved from 0.19301 to 0.19160, saving model to ./model4/80-0.1916.hdf5
#
# Epoch 00081: val_loss did not improve from 0.19160
#
# Epoch 00082: val_loss did not improve from 0.19160
#
# Epoch 00083: val_loss improved from 0.19160 to 0.19151, saving model to ./model4/83-0.1915.hdf5
#
# Epoch 00084: val_loss improved from 0.19151 to 0.18851, saving model to ./model4/84-0.1885.hdf5
#
# Epoch 00085: val_loss improved from 0.18851 to 0.18763, saving model to ./model4/85-0.1876.hdf5
#
# Epoch 00086: val_loss improved from 0.18763 to 0.18740, saving model to ./model4/86-0.1874.hdf5
#
# Epoch 00087: val_loss did not improve from 0.18740
#
# Epoch 00088: val_loss did not improve from 0.18740
#
# Epoch 00089: val_loss improved from 0.18740 to 0.18677, saving model to ./model4/89-0.1868.hdf5
#
# Epoch 00090: val_loss improved from 0.18677 to 0.18411, saving model to ./model4/90-0.1841.hdf5
#
# Epoch 00091: val_loss improved from 0.18411 to 0.18280, saving model to ./model4/91-0.1828.hdf5
#
# Epoch 00092: val_loss did not improve from 0.18280
#
# Epoch 00093: val_loss did not improve from 0.18280
#
# Epoch 00094: val_loss did not improve from 0.18280
#
# Epoch 00095: val_loss improved from 0.18280 to 0.18186, saving model to ./model4/95-0.1819.hdf5
#
# Epoch 00096: val_loss improved from 0.18186 to 0.18092, saving model to ./model4/96-0.1809.hdf5
#
# Epoch 00097: val_loss improved from 0.18092 to 0.18050, saving model to ./model4/97-0.1805.hdf5
#
# Epoch 00098: val_loss improved from 0.18050 to 0.17961, saving model to ./model4/98-0.1796.hdf5
#
# Epoch 00099: val_loss improved from 0.17961 to 0.17938, saving model to ./model4/99-0.1794.hdf5
#
# Epoch 00100: val_loss improved from 0.17938 to 0.17778, saving model to ./model4/100-0.1778.hdf5
# Epoch 00101: val_loss improved from 0.17778 to 0.17638, saving model to ./model4/101-0.1764.hdf5
#
# Epoch 00102: val_loss improved from 0.17638 to 0.17456, saving model to ./model4/102-0.1746.hdf5
#
# Epoch 00103: val_loss improved from 0.17456 to 0.17392, saving model to ./model4/103-0.1739.hdf5
#
# Epoch 00104: val_loss did not improve from 0.17392
#
# Epoch 00105: val_loss did not improve from 0.17392
#
# Epoch 00106: val_loss did not improve from 0.17392
#
# Epoch 00107: val_loss improved from 0.17392 to 0.17043, saving model to ./model4/107-0.1704.hdf5
#
# Epoch 00108: val_loss improved from 0.17043 to 0.16969, saving model to ./model4/108-0.1697.hdf5
#
# Epoch 00109: val_loss did not improve from 0.16969
#
# Epoch 00110: val_loss did not improve from 0.16969
#
# Epoch 00111: val_loss did not improve from 0.16969
#
# Epoch 00112: val_loss improved from 0.16969 to 0.16705, saving model to ./model4/112-0.1671.hdf5
#
# Epoch 00113: val_loss improved from 0.16705 to 0.16645, saving model to ./model4/113-0.1664.hdf5
#
# Epoch 00114: val_loss did not improve from 0.16645
#
# Epoch 00115: val_loss did not improve from 0.16645
#
# Epoch 00116: val_loss did not improve from 0.16645
#
# Epoch 00117: val_loss improved from 0.16645 to 0.16494, saving model to ./model4/117-0.1649.hdf5
#
# Epoch 00118: val_loss improved from 0.16494 to 0.16457, saving model to ./model4/118-0.1646.hdf5
#
# Epoch 00119: val_loss did not improve from 0.16457
#
# Epoch 00120: val_loss did not improve from 0.16457
#
# Epoch 00121: val_loss improved from 0.16457 to 0.16408, saving model to ./model4/121-0.1641.hdf5
#
# Epoch 00122: val_loss improved from 0.16408 to 0.16051, saving model to ./model4/122-0.1605.hdf5
#
# Epoch 00123: val_loss did not improve from 0.16051
#
# Epoch 00124: val_loss did not improve from 0.16051
#
# Epoch 00125: val_loss did not improve from 0.16051
#
# Epoch 00126: val_loss did not improve from 0.16051
#
# Epoch 00127: val_loss improved from 0.16051 to 0.15823, saving model to ./model4/127-0.1582.hdf5
#
# Epoch 00128: val_loss did not improve from 0.15823
#
# Epoch 00129: val_loss did not improve from 0.15823
#
# Epoch 00130: val_loss did not improve from 0.15823
#
# Epoch 00131: val_loss did not improve from 0.15823
#
# Epoch 00132: val_loss improved from 0.15823 to 0.15616, saving model to ./model4/132-0.1562.hdf5
#
# Epoch 00133: val_loss improved from 0.15616 to 0.15537, saving model to ./model4/133-0.1554.hdf5
#
# Epoch 00134: val_loss did not improve from 0.15537
#
# Epoch 00135: val_loss did not improve from 0.15537
#
# Epoch 00136: val_loss improved from 0.15537 to 0.15453, saving model to ./model4/136-0.1545.hdf5
#
# Epoch 00137: val_loss improved from 0.15453 to 0.15347, saving model to ./model4/137-0.1535.hdf5
#
# Epoch 00138: val_loss did not improve from 0.15347
#
# Epoch 00139: val_loss did not improve from 0.15347
#
# Epoch 00140: val_loss improved from 0.15347 to 0.15242, saving model to ./model4/140-0.1524.hdf5
#
# Epoch 00141: val_loss improved from 0.15242 to 0.15128, saving model to ./model4/141-0.1513.hdf5
#
# Epoch 00142: val_loss did not improve from 0.15128
#
# Epoch 00143: val_loss did not improve from 0.15128
#
# Epoch 00144: val_loss did not improve from 0.15128
#
# Epoch 00145: val_loss improved from 0.15128 to 0.14923, saving model to ./model4/145-0.1492.hdf5
#
# Epoch 00146: val_loss improved from 0.14923 to 0.14881, saving model to ./model4/146-0.1488.hdf5
#
# Epoch 00147: val_loss did not improve from 0.14881
#
# Epoch 00148: val_loss did not improve from 0.14881
#
# Epoch 00149: val_loss did not improve from 0.14881
#
# Epoch 00150: val_loss did not improve from 0.14881
#
# Epoch 00151: val_loss did not improve from 0.14881
#
# Epoch 00152: val_loss did not improve from 0.14881
#
# Epoch 00153: val_loss did not improve from 0.14881
#
# Epoch 00154: val_loss improved from 0.14881 to 0.14614, saving model to ./model4/154-0.1461.hdf5
#
# Epoch 00155: val_loss improved from 0.14614 to 0.14429, saving model to ./model4/155-0.1443.hdf5
#
# Epoch 00156: val_loss did not improve from 0.14429
#
# Epoch 00157: val_loss did not improve from 0.14429
#
# Epoch 00158: val_loss did not improve from 0.14429
#
# Epoch 00159: val_loss did not improve from 0.14429
#
# Epoch 00160: val_loss improved from 0.14429 to 0.14333, saving model to ./model4/160-0.1433.hdf5
#
# Epoch 00161: val_loss did not improve from 0.14333
#
# Epoch 00162: val_loss did not improve from 0.14333
#
# Epoch 00163: val_loss improved from 0.14333 to 0.14286, saving model to ./model4/163-0.1429.hdf5
#
# Epoch 00164: val_loss improved from 0.14286 to 0.14070, saving model to ./model4/164-0.1407.hdf5
#
# Epoch 00165: val_loss did not improve from 0.14070
#
# Epoch 00166: val_loss did not improve from 0.14070
#
# Epoch 00167: val_loss did not improve from 0.14070
#
# Epoch 00168: val_loss improved from 0.14070 to 0.13953, saving model to ./model4/168-0.1395.hdf5
#
# Epoch 00169: val_loss improved from 0.13953 to 0.13849, saving model to ./model4/169-0.1385.hdf5
#
# Epoch 00170: val_loss did not improve from 0.13849
#
# Epoch 00171: val_loss did not improve from 0.13849
#
# Epoch 00172: val_loss did not improve from 0.13849
#
# Epoch 00173: val_loss did not improve from 0.13849
#
# Epoch 00174: val_loss did not improve from 0.13849
#
# Epoch 00175: val_loss did not improve from 0.13849
#
# Epoch 00176: val_loss improved from 0.13849 to 0.13560, saving model to ./model4/176-0.1356.hdf5
#
# Epoch 00177: val_loss did not improve from 0.13560
#
# Epoch 00178: val_loss did not improve from 0.13560
#
# Epoch 00179: val_loss did not improve from 0.13560
#
# Epoch 00180: val_loss did not improve from 0.13560
#
# Epoch 00181: val_loss improved from 0.13560 to 0.13347, saving model to ./model4/181-0.1335.hdf5
#
# Epoch 00182: val_loss did not improve from 0.13347
#
# Epoch 00183: val_loss did not improve from 0.13347
#
# Epoch 00184: val_loss did not improve from 0.13347
#
# Epoch 00185: val_loss did not improve from 0.13347
#
# Epoch 00186: val_loss improved from 0.13347 to 0.13258, saving model to ./model4/186-0.1326.hdf5
#
# Epoch 00187: val_loss did not improve from 0.13258
#
# Epoch 00188: val_loss did not improve from 0.13258
#
# Epoch 00189: val_loss did not improve from 0.13258
#
# Epoch 00190: val_loss improved from 0.13258 to 0.13034, saving model to ./model4/190-0.1303.hdf5
#
# Epoch 00191: val_loss did not improve from 0.13034
#
# Epoch 00192: val_loss did not improve from 0.13034
#
# Epoch 00193: val_loss did not improve from 0.13034
#
# Epoch 00194: val_loss improved from 0.13034 to 0.13019, saving model to ./model4/194-0.1302.hdf5
#
# Epoch 00195: val_loss did not improve from 0.13019
#
# Epoch 00196: val_loss did not improve from 0.13019
#
# Epoch 00197: val_loss improved from 0.13019 to 0.12958, saving model to ./model4/197-0.1296.hdf5
#
# Epoch 00198: val_loss improved from 0.12958 to 0.12747, saving model to ./model4/198-0.1275.hdf5
#
# Epoch 00199: val_loss did not improve from 0.12747
#
# Epoch 00200: val_loss did not improve from 0.12747
#
# Epoch 00201: val_loss did not improve from 0.12747
#
# Epoch 00202: val_loss improved from 0.12747 to 0.12668, saving model to ./model4/202-0.1267.hdf5
#
# Epoch 00203: val_loss did not improve from 0.12668
#
# Epoch 00204: val_loss did not improve from 0.12668
#
# Epoch 00205: val_loss did not improve from 0.12668
#
# Epoch 00206: val_loss improved from 0.12668 to 0.12596, saving model to ./model4/206-0.1260.hdf5
#
# Epoch 00207: val_loss did not improve from 0.12596
#
# Epoch 00208: val_loss did not improve from 0.12596
#
# Epoch 00209: val_loss did not improve from 0.12596
#
# Epoch 00210: val_loss did not improve from 0.12596
#
# Epoch 00211: val_loss improved from 0.12596 to 0.12519, saving model to ./model4/211-0.1252.hdf5
#
# Epoch 00212: val_loss did not improve from 0.12519
#
# Epoch 00213: val_loss did not improve from 0.12519
#
# Epoch 00214: val_loss improved from 0.12519 to 0.12512, saving model to ./model4/214-0.1251.hdf5
#
# Epoch 00215: val_loss improved from 0.12512 to 0.12372, saving model to ./model4/215-0.1237.hdf5
#
# Epoch 00216: val_loss did not improve from 0.12372
#
# Epoch 00217: val_loss did not improve from 0.12372
#
# Epoch 00218: val_loss did not improve from 0.12372
#
# Epoch 00219: val_loss did not improve from 0.12372
#
# Epoch 00220: val_loss did not improve from 0.12372
#
# Epoch 00221: val_loss did not improve from 0.12372
#
# Epoch 00222: val_loss did not improve from 0.12372
#
# Epoch 00223: val_loss did not improve from 0.12372
#
# Epoch 00224: val_loss did not improve from 0.12372
#
# Epoch 00225: val_loss did not improve from 0.12372
#
# Epoch 00226: val_loss did not improve from 0.12372
#
# Epoch 00227: val_loss improved from 0.12372 to 0.12193, saving model to ./model4/227-0.1219.hdf5
#
# Epoch 00228: val_loss did not improve from 0.12193
#
# Epoch 00229: val_loss did not improve from 0.12193
#
# Epoch 00230: val_loss improved from 0.12193 to 0.12077, saving model to ./model4/230-0.1208.hdf5
#
# Epoch 00231: val_loss improved from 0.12077 to 0.11941, saving model to ./model4/231-0.1194.hdf5
#
# Epoch 00232: val_loss did not improve from 0.11941
#
# Epoch 00233: val_loss did not improve from 0.11941
#
# Epoch 00234: val_loss improved from 0.11941 to 0.11856, saving model to ./model4/234-0.1186.hdf5
#
# Epoch 00235: val_loss did not improve from 0.11856
#
# Epoch 00236: val_loss did not improve from 0.11856
#
# Epoch 00237: val_loss did not improve from 0.11856
#
# Epoch 00238: val_loss improved from 0.11856 to 0.11786, saving model to ./model4/238-0.1179.hdf5
#
# Epoch 00239: val_loss did not improve from 0.11786
#
# Epoch 00240: val_loss did not improve from 0.11786
#
# Epoch 00241: val_loss did not improve from 0.11786
#
# Epoch 00242: val_loss improved from 0.11786 to 0.11566, saving model to ./model4/242-0.1157.hdf5
#
# Epoch 00243: val_loss did not improve from 0.11566
#
# Epoch 00244: val_loss did not improve from 0.11566
#
# Epoch 00245: val_loss did not improve from 0.11566
#
# Epoch 00246: val_loss did not improve from 0.11566
#
# Epoch 00247: val_loss did not improve from 0.11566
#
# Epoch 00248: val_loss did not improve from 0.11566
#
# Epoch 00249: val_loss improved from 0.11566 to 0.11557, saving model to ./model4/249-0.1156.hdf5
#
# Epoch 00250: val_loss improved from 0.11557 to 0.11351, saving model to ./model4/250-0.1135.hdf5
# Epoch 00251: val_loss did not improve from 0.11351
#
# Epoch 00252: val_loss did not improve from 0.11351
#
# Epoch 00253: val_loss did not improve from 0.11351
#
# Epoch 00254: val_loss improved from 0.11351 to 0.11333, saving model to ./model4/254-0.1133.hdf5
#
# Epoch 00255: val_loss did not improve from 0.11333
#
# Epoch 00256: val_loss did not improve from 0.11333
#
# Epoch 00257: val_loss did not improve from 0.11333
#
# Epoch 00258: val_loss improved from 0.11333 to 0.11259, saving model to ./model4/258-0.1126.hdf5
#
# Epoch 00259: val_loss did not improve from 0.11259
#
# Epoch 00260: val_loss did not improve from 0.11259
#
# Epoch 00261: val_loss improved from 0.11259 to 0.11235, saving model to ./model4/261-0.1124.hdf5
#
# Epoch 00262: val_loss improved from 0.11235 to 0.11147, saving model to ./model4/262-0.1115.hdf5
#
# Epoch 00263: val_loss did not improve from 0.11147
#
# Epoch 00264: val_loss did not improve from 0.11147
#
# Epoch 00265: val_loss did not improve from 0.11147
#
# Epoch 00266: val_loss improved from 0.11147 to 0.10846, saving model to ./model4/266-0.1085.hdf5
#
# Epoch 00267: val_loss did not improve from 0.10846
#
# Epoch 00268: val_loss did not improve from 0.10846
#
# Epoch 00269: val_loss did not improve from 0.10846
#
# Epoch 00270: val_loss did not improve from 0.10846
#
# Epoch 00271: val_loss did not improve from 0.10846
#
# Epoch 00272: val_loss did not improve from 0.10846
#
# Epoch 00273: val_loss did not improve from 0.10846
#
# Epoch 00274: val_loss did not improve from 0.10846
#
# Epoch 00275: val_loss did not improve from 0.10846
#
# Epoch 00276: val_loss did not improve from 0.10846
#
# Epoch 00277: val_loss did not improve from 0.10846
#
# Epoch 00278: val_loss did not improve from 0.10846
#
# Epoch 00279: val_loss improved from 0.10846 to 0.10796, saving model to ./model4/279-0.1080.hdf5
#
# Epoch 00280: val_loss did not improve from 0.10796
#
# Epoch 00281: val_loss did not improve from 0.10796
#
# Epoch 00282: val_loss did not improve from 0.10796
#
# Epoch 00283: val_loss did not improve from 0.10796
#
# Epoch 00284: val_loss did not improve from 0.10796
#
# Epoch 00285: val_loss did not improve from 0.10796
#
# Epoch 00286: val_loss did not improve from 0.10796
#
# Epoch 00287: val_loss improved from 0.10796 to 0.10620, saving model to ./model4/287-0.1062.hdf5
#
# Epoch 00288: val_loss did not improve from 0.10620
#
# Epoch 00289: val_loss did not improve from 0.10620
#
# Epoch 00290: val_loss did not improve from 0.10620
#
# Epoch 00291: val_loss did not improve from 0.10620
#
# Epoch 00292: val_loss improved from 0.10620 to 0.10412, saving model to ./model4/292-0.1041.hdf5
#
# Epoch 00293: val_loss did not improve from 0.10412
#
# Epoch 00294: val_loss did not improve from 0.10412
#
# Epoch 00295: val_loss did not improve from 0.10412
#
# Epoch 00296: val_loss did not improve from 0.10412
#
# Epoch 00297: val_loss did not improve from 0.10412
#
# Epoch 00298: val_loss did not improve from 0.10412
#
# Epoch 00299: val_loss improved from 0.10412 to 0.10023, saving model to ./model4/299-0.1002.hdf5
#
# Epoch 00300: val_loss did not improve from 0.10023
#
# Epoch 00301: val_loss did not improve from 0.10023
#
# Epoch 00302: val_loss did not improve from 0.10023
#
# Epoch 00303: val_loss did not improve from 0.10023
#
# Epoch 00304: val_loss did not improve from 0.10023
#
# Epoch 00305: val_loss did not improve from 0.10023
#
# Epoch 00306: val_loss improved from 0.10023 to 0.09895, saving model to ./model4/306-0.0989.hdf5
#
# Epoch 00307: val_loss did not improve from 0.09895
#
# Epoch 00308: val_loss did not improve from 0.09895
#
# Epoch 00309: val_loss did not improve from 0.09895
#
# Epoch 00310: val_loss improved from 0.09895 to 0.09879, saving model to ./model4/310-0.0988.hdf5
#
# Epoch 00311: val_loss did not improve from 0.09879
#
# Epoch 00312: val_loss did not improve from 0.09879
#
# Epoch 00313: val_loss did not improve from 0.09879
#
# Epoch 00314: val_loss did not improve from 0.09879
#
# Epoch 00315: val_loss did not improve from 0.09879
#
# Epoch 00316: val_loss did not improve from 0.09879
#
# Epoch 00317: val_loss did not improve from 0.09879
#
# Epoch 00318: val_loss did not improve from 0.09879
#
# Epoch 00319: val_loss did not improve from 0.09879
#
# Epoch 00320: val_loss improved from 0.09879 to 0.09786, saving model to ./model4/320-0.0979.hdf5
#
# Epoch 00321: val_loss did not improve from 0.09786
#
# Epoch 00322: val_loss did not improve from 0.09786
#
# Epoch 00323: val_loss improved from 0.09786 to 0.09609, saving model to ./model4/323-0.0961.hdf5
#
# Epoch 00324: val_loss did not improve from 0.09609
#
# Epoch 00325: val_loss did not improve from 0.09609
#
# Epoch 00326: val_loss did not improve from 0.09609
#
# Epoch 00327: val_loss did not improve from 0.09609
#
# Epoch 00328: val_loss did not improve from 0.09609
#
# Epoch 00329: val_loss did not improve from 0.09609
#
# Epoch 00330: val_loss improved from 0.09609 to 0.09424, saving model to ./model4/330-0.0942.hdf5
#
# Epoch 00331: val_loss did not improve from 0.09424
#
# Epoch 00332: val_loss did not improve from 0.09424
#
# Epoch 00333: val_loss did not improve from 0.09424
#
# Epoch 00334: val_loss improved from 0.09424 to 0.09334, saving model to ./model4/334-0.0933.hdf5
#
# Epoch 00335: val_loss did not improve from 0.09334
#
# Epoch 00336: val_loss did not improve from 0.09334
#
# Epoch 00337: val_loss improved from 0.09334 to 0.09183, saving model to ./model4/337-0.0918.hdf5
#
# Epoch 00338: val_loss did not improve from 0.09183
#
# Epoch 00339: val_loss did not improve from 0.09183
#
# Epoch 00340: val_loss did not improve from 0.09183
#
# Epoch 00341: val_loss did not improve from 0.09183
#
# Epoch 00342: val_loss did not improve from 0.09183
#
# Epoch 00343: val_loss did not improve from 0.09183
#
# Epoch 00344: val_loss did not improve from 0.09183
#
# Epoch 00345: val_loss did not improve from 0.09183
#
# Epoch 00346: val_loss did not improve from 0.09183
#
# Epoch 00347: val_loss did not improve from 0.09183
#
# Epoch 00348: val_loss did not improve from 0.09183
#
# Epoch 00349: val_loss did not improve from 0.09183
#
# Epoch 00350: val_loss did not improve from 0.09183
#
# Epoch 00351: val_loss did not improve from 0.09183
#
# Epoch 00352: val_loss did not improve from 0.09183
#
# Epoch 00353: val_loss did not improve from 0.09183
#
# Epoch 00354: val_loss did not improve from 0.09183
#
# Epoch 00355: val_loss did not improve from 0.09183
#
# Epoch 00356: val_loss improved from 0.09183 to 0.09105, saving model to ./model4/356-0.0910.hdf5
#
# Epoch 00357: val_loss did not improve from 0.09105
#
# Epoch 00358: val_loss did not improve from 0.09105
#
# Epoch 00359: val_loss did not improve from 0.09105
#
# Epoch 00360: val_loss did not improve from 0.09105
#
# Epoch 00361: val_loss did not improve from 0.09105
#
# Epoch 00362: val_loss improved from 0.09105 to 0.08944, saving model to ./model4/362-0.0894.hdf5
#
# Epoch 00363: val_loss did not improve from 0.08944
#
# Epoch 00364: val_loss did not improve from 0.08944
#
# Epoch 00365: val_loss did not improve from 0.08944
#
# Epoch 00366: val_loss did not improve from 0.08944
#
# Epoch 00367: val_loss did not improve from 0.08944
#
# Epoch 00368: val_loss did not improve from 0.08944
#
# Epoch 00369: val_loss did not improve from 0.08944
#
# Epoch 00370: val_loss improved from 0.08944 to 0.08660, saving model to ./model4/370-0.0866.hdf5
#
# Epoch 00371: val_loss did not improve from 0.08660
#
# Epoch 00372: val_loss did not improve from 0.08660
#
# Epoch 00373: val_loss did not improve from 0.08660
#
# Epoch 00374: val_loss improved from 0.08660 to 0.08533, saving model to ./model4/374-0.0853.hdf5
#
# Epoch 00375: val_loss did not improve from 0.08533
#
# Epoch 00376: val_loss did not improve from 0.08533
#
# Epoch 00377: val_loss did not improve from 0.08533
#
# Epoch 00378: val_loss improved from 0.08533 to 0.08513, saving model to ./model4/378-0.0851.hdf5
#
# Epoch 00379: val_loss did not improve from 0.08513
#
# Epoch 00380: val_loss did not improve from 0.08513
#
# Epoch 00381: val_loss did not improve from 0.08513
#
# Epoch 00382: val_loss improved from 0.08513 to 0.08492, saving model to ./model4/382-0.0849.hdf5
#
# Epoch 00383: val_loss did not improve from 0.08492
#
# Epoch 00384: val_loss did not improve from 0.08492
#
# Epoch 00385: val_loss did not improve from 0.08492
#
# Epoch 00386: val_loss improved from 0.08492 to 0.08383, saving model to ./model4/386-0.0838.hdf5
#
# Epoch 00387: val_loss did not improve from 0.08383
#
# Epoch 00388: val_loss did not improve from 0.08383
#
# Epoch 00389: val_loss did not improve from 0.08383
#
# Epoch 00390: val_loss improved from 0.08383 to 0.08312, saving model to ./model4/390-0.0831.hdf5
#
# Epoch 00391: val_loss did not improve from 0.08312
# Epoch 00392: val_loss did not improve from 0.08312
#
# Epoch 00393: val_loss did not improve from 0.08312
#
# Epoch 00394: val_loss did not improve from 0.08312
#
# Epoch 00395: val_loss did not improve from 0.08312
#
# Epoch 00396: val_loss did not improve from 0.08312
#
# Epoch 00397: val_loss improved from 0.08312 to 0.08088, saving model to ./model4/397-0.0809.hdf5
#
# Epoch 00398: val_loss did not improve from 0.08088
#
# Epoch 00399: val_loss did not improve from 0.08088
#
# Epoch 00400: val_loss did not improve from 0.08088
#
# Epoch 00401: val_loss did not improve from 0.08088
#
# Epoch 00402: val_loss did not improve from 0.08088
#
# Epoch 00403: val_loss did not improve from 0.08088
#
# Epoch 00404: val_loss did not improve from 0.08088
#
# Epoch 00405: val_loss did not improve from 0.08088
#
# Epoch 00406: val_loss did not improve from 0.08088
#
# Epoch 00407: val_loss improved from 0.08088 to 0.07971, saving model to ./model4/407-0.0797.hdf5
#
# Epoch 00408: val_loss did not improve from 0.07971
#
# Epoch 00409: val_loss did not improve from 0.07971
#
# Epoch 00410: val_loss did not improve from 0.07971
#
# Epoch 00411: val_loss did not improve from 0.07971
#
# Epoch 00412: val_loss did not improve from 0.07971
#
# Epoch 00413: val_loss did not improve from 0.07971
#
# Epoch 00414: val_loss did not improve from 0.07971
#
# Epoch 00415: val_loss did not improve from 0.07971
#
# Epoch 00416: val_loss did not improve from 0.07971
#
# Epoch 00417: val_loss did not improve from 0.07971
#
# Epoch 00418: val_loss improved from 0.07971 to 0.07931, saving model to ./model4/418-0.0793.hdf5
#
# Epoch 00419: val_loss did not improve from 0.07931
#
# Epoch 00420: val_loss did not improve from 0.07931
#
# Epoch 00421: val_loss improved from 0.07931 to 0.07722, saving model to ./model4/421-0.0772.hdf5
#
# Epoch 00422: val_loss did not improve from 0.07722
#
# Epoch 00423: val_loss did not improve from 0.07722
#
# Epoch 00424: val_loss did not improve from 0.07722
#
# Epoch 00425: val_loss improved from 0.07722 to 0.07603, saving model to ./model4/425-0.0760.hdf5
#
# Epoch 00426: val_loss did not improve from 0.07603
#
# Epoch 00427: val_loss did not improve from 0.07603
#
# Epoch 00428: val_loss did not improve from 0.07603
#
# Epoch 00429: val_loss improved from 0.07603 to 0.07597, saving model to ./model4/429-0.0760.hdf5
#
# Epoch 00430: val_loss did not improve from 0.07597
#
# Epoch 00431: val_loss did not improve from 0.07597
#
# Epoch 00432: val_loss improved from 0.07597 to 0.07554, saving model to ./model4/432-0.0755.hdf5
#
# Epoch 00433: val_loss did not improve from 0.07554
#
# Epoch 00434: val_loss did not improve from 0.07554
#
# Epoch 00435: val_loss did not improve from 0.07554
#
# Epoch 00436: val_loss did not improve from 0.07554
#
# Epoch 00437: val_loss did not improve from 0.07554
#
# Epoch 00438: val_loss did not improve from 0.07554
#
# Epoch 00439: val_loss improved from 0.07554 to 0.07481, saving model to ./model4/439-0.0748.hdf5
#
# Epoch 00440: val_loss did not improve from 0.07481
#
# Epoch 00441: val_loss did not improve from 0.07481
#
# Epoch 00442: val_loss did not improve from 0.07481
#
# Epoch 00443: val_loss did not improve from 0.07481
#
# Epoch 00444: val_loss did not improve from 0.07481
#
# Epoch 00445: val_loss did not improve from 0.07481
#
# Epoch 00446: val_loss did not improve from 0.07481
#
# Epoch 00447: val_loss did not improve from 0.07481
#
# Epoch 00448: val_loss improved from 0.07481 to 0.07315, saving model to ./model4/448-0.0731.hdf5
#
# Epoch 00449: val_loss did not improve from 0.07315
#
# Epoch 00450: val_loss did not improve from 0.07315
#
# Epoch 00451: val_loss did not improve from 0.07315
#
# Epoch 00452: val_loss improved from 0.07315 to 0.07290, saving model to ./model4/452-0.0729.hdf5
#
# Epoch 00453: val_loss did not improve from 0.07290
#
# Epoch 00454: val_loss did not improve from 0.07290
#
# Epoch 00455: val_loss did not improve from 0.07290
#
# Epoch 00456: val_loss did not improve from 0.07290
#
# Epoch 00457: val_loss did not improve from 0.07290
#
# Epoch 00458: val_loss did not improve from 0.07290
#
# Epoch 00459: val_loss improved from 0.07290 to 0.07173, saving model to ./model4/459-0.0717.hdf5
#
# Epoch 00460: val_loss did not improve from 0.07173
#
# Epoch 00461: val_loss did not improve from 0.07173
#
# Epoch 00462: val_loss did not improve from 0.07173
#
# Epoch 00463: val_loss did not improve from 0.07173
#
# Epoch 00464: val_loss did not improve from 0.07173
#
# Epoch 00465: val_loss did not improve from 0.07173
#
# Epoch 00466: val_loss did not improve from 0.07173
#
# Epoch 00467: val_loss did not improve from 0.07173
#
# Epoch 00468: val_loss did not improve from 0.07173
#
# Epoch 00469: val_loss improved from 0.07173 to 0.07164, saving model to ./model4/469-0.0716.hdf5
#
# Epoch 00470: val_loss did not improve from 0.07164
#
# Epoch 00471: val_loss did not improve from 0.07164
#
# Epoch 00472: val_loss did not improve from 0.07164
#
# Epoch 00473: val_loss did not improve from 0.07164
#
# Epoch 00474: val_loss did not improve from 0.07164
#
# Epoch 00475: val_loss improved from 0.07164 to 0.07045, saving model to ./model4/475-0.0704.hdf5
#
# Epoch 00476: val_loss did not improve from 0.07045
#
# Epoch 00477: val_loss did not improve from 0.07045
#
# Epoch 00478: val_loss did not improve from 0.07045
#
# Epoch 00479: val_loss did not improve from 0.07045
#
# Epoch 00480: val_loss did not improve from 0.07045
#
# Epoch 00481: val_loss did not improve from 0.07045
#
# Epoch 00482: val_loss did not improve from 0.07045
#
# Epoch 00483: val_loss did not improve from 0.07045
#
# Epoch 00484: val_loss did not improve from 0.07045
#
# Epoch 00485: val_loss did not improve from 0.07045
#
# Epoch 00486: val_loss did not improve from 0.07045
#
# Epoch 00487: val_loss did not improve from 0.07045
#
# Epoch 00488: val_loss improved from 0.07045 to 0.07014, saving model to ./model4/488-0.0701.hdf5
#
# Epoch 00489: val_loss did not improve from 0.07014
#
# Epoch 00490: val_loss did not improve from 0.07014
#
# Epoch 00491: val_loss did not improve from 0.07014
#
# Epoch 00492: val_loss improved from 0.07014 to 0.06997, saving model to ./model4/492-0.0700.hdf5
#
# Epoch 00493: val_loss did not improve from 0.06997
#
# Epoch 00494: val_loss did not improve from 0.06997
#
# Epoch 00495: val_loss improved from 0.06997 to 0.06991, saving model to ./model4/495-0.0699.hdf5
#
# Epoch 00496: val_loss did not improve from 0.06991
#
# Epoch 00497: val_loss did not improve from 0.06991
#
# Epoch 00498: val_loss improved from 0.06991 to 0.06820, saving model to ./model4/498-0.0682.hdf5
#
# Epoch 00499: val_loss did not improve from 0.06820
#
# Epoch 00500: val_loss did not improve from 0.06820
#
# Epoch 00501: val_loss did not improve from 0.06820
#
# Epoch 00502: val_loss did not improve from 0.06820
#
# Epoch 00503: val_loss did not improve from 0.06820
#
# Epoch 00504: val_loss did not improve from 0.06820
#
# Epoch 00505: val_loss did not improve from 0.06820
#
# Epoch 00506: val_loss improved from 0.06820 to 0.06729, saving model to ./model4/506-0.0673.hdf5
#
# Epoch 00507: val_loss did not improve from 0.06729
#
# Epoch 00508: val_loss did not improve from 0.06729
#
# Epoch 00509: val_loss did not improve from 0.06729
#
# Epoch 00510: val_loss did not improve from 0.06729
#
# Epoch 00511: val_loss did not improve from 0.06729
#
# Epoch 00512: val_loss did not improve from 0.06729
#
# Epoch 00513: val_loss improved from 0.06729 to 0.06709, saving model to ./model4/513-0.0671.hdf5
#
# Epoch 00514: val_loss did not improve from 0.06709
#
# Epoch 00515: val_loss did not improve from 0.06709
#
# Epoch 00516: val_loss improved from 0.06709 to 0.06624, saving model to ./model4/516-0.0662.hdf5
#
# Epoch 00517: val_loss did not improve from 0.06624
#
# Epoch 00518: val_loss did not improve from 0.06624
#
# Epoch 00519: val_loss did not improve from 0.06624
#
# Epoch 00520: val_loss did not improve from 0.06624
#
# Epoch 00521: val_loss did not improve from 0.06624
#
# Epoch 00522: val_loss did not improve from 0.06624
#
# Epoch 00523: val_loss improved from 0.06624 to 0.06394, saving model to ./model4/523-0.0639.hdf5
#
# Epoch 00524: val_loss did not improve from 0.06394
#
# Epoch 00525: val_loss did not improve from 0.06394
#
# Epoch 00526: val_loss did not improve from 0.06394
#
# Epoch 00527: val_loss improved from 0.06394 to 0.06374, saving model to ./model4/527-0.0637.hdf5
#
# Epoch 00528: val_loss did not improve from 0.06374
#
# Epoch 00529: val_loss did not improve from 0.06374
#
# Epoch 00530: val_loss improved from 0.06374 to 0.06310, saving model to ./model4/530-0.0631.hdf5
#
# Epoch 00531: val_loss did not improve from 0.06310
#
# Epoch 00532: val_loss did not improve from 0.06310
#
# Epoch 00533: val_loss did not improve from 0.06310
#
# Epoch 00534: val_loss improved from 0.06310 to 0.06292, saving model to ./model4/534-0.0629.hdf5
#
# Epoch 00535: val_loss did not improve from 0.06292
#
# Epoch 00536: val_loss did not improve from 0.06292
#
# Epoch 00537: val_loss did not improve from 0.06292
#
# Epoch 00538: val_loss did not improve from 0.06292
#
# Epoch 00539: val_loss did not improve from 0.06292
#
# Epoch 00540: val_loss improved from 0.06292 to 0.06284, saving model to ./model4/540-0.0628.hdf5
#
# Epoch 00541: val_loss did not improve from 0.06284
#
# Epoch 00542: val_loss did not improve from 0.06284
#
# Epoch 00543: val_loss improved from 0.06284 to 0.06237, saving model to ./model4/543-0.0624.hdf5
#
# Epoch 00544: val_loss did not improve from 0.06237
#
# Epoch 00545: val_loss did not improve from 0.06237
#
# Epoch 00546: val_loss did not improve from 0.06237
#
# Epoch 00547: val_loss improved from 0.06237 to 0.06176, saving model to ./model4/547-0.0618.hdf5
# Epoch 00548: val_loss did not improve from 0.06176
#
# Epoch 00549: val_loss did not improve from 0.06176
#
# Epoch 00550: val_loss did not improve from 0.06176
#
# Epoch 00551: val_loss did not improve from 0.06176
#
# Epoch 00552: val_loss did not improve from 0.06176
#
# Epoch 00553: val_loss improved from 0.06176 to 0.06167, saving model to ./model4/553-0.0617.hdf5
#
# Epoch 00554: val_loss improved from 0.06167 to 0.06129, saving model to ./model4/554-0.0613.hdf5
#
# Epoch 00555: val_loss did not improve from 0.06129
#
# Epoch 00556: val_loss did not improve from 0.06129
#
# Epoch 00557: val_loss did not improve from 0.06129
#
# Epoch 00558: val_loss did not improve from 0.06129
#
# Epoch 00559: val_loss did not improve from 0.06129
#
# Epoch 00560: val_loss improved from 0.06129 to 0.06117, saving model to ./model4/560-0.0612.hdf5
#
# Epoch 00561: val_loss did not improve from 0.06117
#
# Epoch 00562: val_loss did not improve from 0.06117
#
# Epoch 00563: val_loss did not improve from 0.06117
#
# Epoch 00564: val_loss did not improve from 0.06117
#
# Epoch 00565: val_loss did not improve from 0.06117
#
# Epoch 00566: val_loss improved from 0.06117 to 0.06079, saving model to ./model4/566-0.0608.hdf5
#
# Epoch 00567: val_loss did not improve from 0.06079
#
# Epoch 00568: val_loss did not improve from 0.06079
#
# Epoch 00569: val_loss did not improve from 0.06079
#
# Epoch 00570: val_loss did not improve from 0.06079
#
# Epoch 00571: val_loss did not improve from 0.06079
#
# Epoch 00572: val_loss did not improve from 0.06079
#
# Epoch 00573: val_loss did not improve from 0.06079
#
# Epoch 00574: val_loss improved from 0.06079 to 0.05923, saving model to ./model4/574-0.0592.hdf5
#
# Epoch 00575: val_loss did not improve from 0.05923
#
# Epoch 00576: val_loss did not improve from 0.05923
#
# Epoch 00577: val_loss did not improve from 0.05923
#
# Epoch 00578: val_loss did not improve from 0.05923
#
# Epoch 00579: val_loss did not improve from 0.05923
#
# Epoch 00580: val_loss improved from 0.05923 to 0.05798, saving model to ./model4/580-0.0580.hdf5
#
# Epoch 00581: val_loss did not improve from 0.05798
#
# Epoch 00582: val_loss did not improve from 0.05798
#
# Epoch 00583: val_loss did not improve from 0.05798
#
# Epoch 00584: val_loss did not improve from 0.05798
#
# Epoch 00585: val_loss did not improve from 0.05798
#
# Epoch 00586: val_loss did not improve from 0.05798
#
# Epoch 00587: val_loss did not improve from 0.05798
#
# Epoch 00588: val_loss did not improve from 0.05798
#
# Epoch 00589: val_loss did not improve from 0.05798
#
# Epoch 00590: val_loss did not improve from 0.05798
#
# Epoch 00591: val_loss did not improve from 0.05798
#
# Epoch 00592: val_loss did not improve from 0.05798
#
# Epoch 00593: val_loss did not improve from 0.05798
#
# Epoch 00594: val_loss did not improve from 0.05798
#
# Epoch 00595: val_loss did not improve from 0.05798
#
# Epoch 00596: val_loss did not improve from 0.05798
#
# Epoch 00597: val_loss did not improve from 0.05798
#
# Epoch 00598: val_loss improved from 0.05798 to 0.05691, saving model to ./model4/598-0.0569.hdf5
#
# Epoch 00599: val_loss did not improve from 0.05691
#
# Epoch 00600: val_loss did not improve from 0.05691
#
# Epoch 00601: val_loss did not improve from 0.05691
#
# Epoch 00602: val_loss did not improve from 0.05691
#
# Epoch 00603: val_loss did not improve from 0.05691
#
# Epoch 00604: val_loss did not improve from 0.05691
#
# Epoch 00605: val_loss did not improve from 0.05691
#
# Epoch 00606: val_loss did not improve from 0.05691
#
# Epoch 00607: val_loss did not improve from 0.05691
#
# Epoch 00608: val_loss improved from 0.05691 to 0.05690, saving model to ./model4/608-0.0569.hdf5
#
# Epoch 00609: val_loss did not improve from 0.05690
#
# Epoch 00610: val_loss did not improve from 0.05690
#
# Epoch 00611: val_loss improved from 0.05690 to 0.05568, saving model to ./model4/611-0.0557.hdf5
#
# Epoch 00612: val_loss did not improve from 0.05568
#
# Epoch 00613: val_loss did not improve from 0.05568
#
# Epoch 00614: val_loss improved from 0.05568 to 0.05556, saving model to ./model4/614-0.0556.hdf5
#
# Epoch 00615: val_loss did not improve from 0.05556
#
# Epoch 00616: val_loss did not improve from 0.05556
#
# Epoch 00617: val_loss did not improve from 0.05556
#
# Epoch 00618: val_loss improved from 0.05556 to 0.05540, saving model to ./model4/618-0.0554.hdf5
#
# Epoch 00619: val_loss did not improve from 0.05540
#
# Epoch 00620: val_loss did not improve from 0.05540
#
# Epoch 00621: val_loss improved from 0.05540 to 0.05482, saving model to ./model4/621-0.0548.hdf5
#
# Epoch 00622: val_loss did not improve from 0.05482
#
# Epoch 00623: val_loss did not improve from 0.05482
#
# Epoch 00624: val_loss did not improve from 0.05482
#
# Epoch 00625: val_loss improved from 0.05482 to 0.05387, saving model to ./model4/625-0.0539.hdf5
#
# Epoch 00626: val_loss did not improve from 0.05387
#
# Epoch 00627: val_loss did not improve from 0.05387
#
# Epoch 00628: val_loss improved from 0.05387 to 0.05371, saving model to ./model4/628-0.0537.hdf5
#
# Epoch 00629: val_loss did not improve from 0.05371
#
# Epoch 00630: val_loss did not improve from 0.05371
#
# Epoch 00631: val_loss did not improve from 0.05371
#
# Epoch 00632: val_loss did not improve from 0.05371
#
# Epoch 00633: val_loss did not improve from 0.05371
#
# Epoch 00634: val_loss did not improve from 0.05371
#
# Epoch 00635: val_loss did not improve from 0.05371
#
# Epoch 00636: val_loss did not improve from 0.05371
#
# Epoch 00637: val_loss did not improve from 0.05371
#
# Epoch 00638: val_loss did not improve from 0.05371
#
# Epoch 00639: val_loss did not improve from 0.05371
#
# Epoch 00640: val_loss did not improve from 0.05371
#
# Epoch 00641: val_loss did not improve from 0.05371
#
# Epoch 00642: val_loss did not improve from 0.05371
#
# Epoch 00643: val_loss did not improve from 0.05371
#
# Epoch 00644: val_loss did not improve from 0.05371
#
# Epoch 00645: val_loss improved from 0.05371 to 0.05346, saving model to ./model4/645-0.0535.hdf5
#
# Epoch 00646: val_loss did not improve from 0.05346
#
# Epoch 00647: val_loss did not improve from 0.05346
#
# Epoch 00648: val_loss improved from 0.05346 to 0.05317, saving model to ./model4/648-0.0532.hdf5
#
# Epoch 00649: val_loss did not improve from 0.05317
#
# Epoch 00650: val_loss did not improve from 0.05317
#
# Epoch 00651: val_loss did not improve from 0.05317
#
# Epoch 00652: val_loss did not improve from 0.05317
#
# Epoch 00653: val_loss did not improve from 0.05317
#
# Epoch 00654: val_loss did not improve from 0.05317
#
# Epoch 00655: val_loss did not improve from 0.05317
#
# Epoch 00656: val_loss did not improve from 0.05317
#
# Epoch 00657: val_loss did not improve from 0.05317
#
# Epoch 00658: val_loss did not improve from 0.05317
#
# Epoch 00659: val_loss did not improve from 0.05317
#
# Epoch 00660: val_loss did not improve from 0.05317
#
# Epoch 00661: val_loss did not improve from 0.05317
#
# Epoch 00662: val_loss improved from 0.05317 to 0.05180, saving model to ./model4/662-0.0518.hdf5
#
# Epoch 00663: val_loss did not improve from 0.05180
#
# Epoch 00664: val_loss did not improve from 0.05180
#
# Epoch 00665: val_loss did not improve from 0.05180
#
# Epoch 00666: val_loss did not improve from 0.05180
#
# Epoch 00667: val_loss did not improve from 0.05180
#
# Epoch 00668: val_loss did not improve from 0.05180
#
# Epoch 00669: val_loss improved from 0.05180 to 0.05085, saving model to ./model4/669-0.0508.hdf5
#
# Epoch 00670: val_loss did not improve from 0.05085
#
# Epoch 00671: val_loss improved from 0.05085 to 0.05054, saving model to ./model4/671-0.0505.hdf5
#
# Epoch 00672: val_loss did not improve from 0.05054
#
# Epoch 00673: val_loss did not improve from 0.05054
#
# Epoch 00674: val_loss did not improve from 0.05054
#
# Epoch 00675: val_loss did not improve from 0.05054
#
# Epoch 00676: val_loss did not improve from 0.05054
#
# Epoch 00677: val_loss improved from 0.05054 to 0.04936, saving model to ./model4/677-0.0494.hdf5
#
# Epoch 00678: val_loss did not improve from 0.04936
#
# Epoch 00679: val_loss did not improve from 0.04936
#
# Epoch 00680: val_loss improved from 0.04936 to 0.04874, saving model to ./model4/680-0.0487.hdf5
#
# Epoch 00681: val_loss did not improve from 0.04874
#
# Epoch 00682: val_loss did not improve from 0.04874
#
# Epoch 00683: val_loss did not improve from 0.04874
#
# Epoch 00684: val_loss did not improve from 0.04874
#
# Epoch 00685: val_loss did not improve from 0.04874
#
# Epoch 00686: val_loss did not improve from 0.04874
#
# Epoch 00687: val_loss did not improve from 0.04874
#
# Epoch 00688: val_loss did not improve from 0.04874
#
# Epoch 00689: val_loss did not improve from 0.04874
#
# Epoch 00690: val_loss did not improve from 0.04874
#
# Epoch 00691: val_loss did not improve from 0.04874
#
# Epoch 00692: val_loss did not improve from 0.04874
#
# Epoch 00693: val_loss did not improve from 0.04874
#
# Epoch 00694: val_loss did not improve from 0.04874
#
# Epoch 00695: val_loss did not improve from 0.04874
#
# Epoch 00696: val_loss did not improve from 0.04874
#
# Epoch 00697: val_loss did not improve from 0.04874
#
# Epoch 00698: val_loss did not improve from 0.04874
#
# Epoch 00699: val_loss did not improve from 0.04874
#
# Epoch 00700: val_loss did not improve from 0.04874
#
# Epoch 00701: val_loss did not improve from 0.04874
#
# Epoch 00702: val_loss did not improve from 0.04874
#
# Epoch 00703: val_loss did not improve from 0.04874
#
# Epoch 00704: val_loss did not improve from 0.04874
# Epoch 00705: val_loss improved from 0.04874 to 0.04836, saving model to ./model4/705-0.0484.hdf5
#
# Epoch 00706: val_loss improved from 0.04836 to 0.04776, saving model to ./model4/706-0.0478.hdf5
#
# Epoch 00707: val_loss did not improve from 0.04776
#
# Epoch 00708: val_loss did not improve from 0.04776
#
# Epoch 00709: val_loss did not improve from 0.04776
#
# Epoch 00710: val_loss did not improve from 0.04776
#
# Epoch 00711: val_loss did not improve from 0.04776
#
# Epoch 00712: val_loss did not improve from 0.04776
#
# Epoch 00713: val_loss improved from 0.04776 to 0.04642, saving model to ./model4/713-0.0464.hdf5
#
# Epoch 00714: val_loss improved from 0.04642 to 0.04425, saving model to ./model4/714-0.0443.hdf5
#
# Epoch 00715: val_loss improved from 0.04425 to 0.04412, saving model to ./model4/715-0.0441.hdf5
#
# Epoch 00716: val_loss did not improve from 0.04412
#
# Epoch 00717: val_loss improved from 0.04412 to 0.04351, saving model to ./model4/717-0.0435.hdf5
#
# Epoch 00718: val_loss improved from 0.04351 to 0.04119, saving model to ./model4/718-0.0412.hdf5
#
# Epoch 00719: val_loss did not improve from 0.04119
#
# Epoch 00720: val_loss did not improve from 0.04119
#
# Epoch 00721: val_loss did not improve from 0.04119
#
# Epoch 00722: val_loss did not improve from 0.04119
#
# Epoch 00723: val_loss did not improve from 0.04119
#
# Epoch 00724: val_loss did not improve from 0.04119
#
# Epoch 00725: val_loss did not improve from 0.04119
#
# Epoch 00726: val_loss did not improve from 0.04119
#
# Epoch 00727: val_loss did not improve from 0.04119
#
# Epoch 00728: val_loss did not improve from 0.04119
#
# Epoch 00729: val_loss did not improve from 0.04119
#
# Epoch 00730: val_loss did not improve from 0.04119
#
# Epoch 00731: val_loss did not improve from 0.04119
#
# Epoch 00732: val_loss did not improve from 0.04119
#
# Epoch 00733: val_loss did not improve from 0.04119
#
# Epoch 00734: val_loss did not improve from 0.04119
#
# Epoch 00735: val_loss did not improve from 0.04119
#
# Epoch 00736: val_loss did not improve from 0.04119
#
# Epoch 00737: val_loss did not improve from 0.04119
#
# Epoch 00738: val_loss did not improve from 0.04119
#
# Epoch 00739: val_loss did not improve from 0.04119
#
# Epoch 00740: val_loss did not improve from 0.04119
#
# Epoch 00741: val_loss did not improve from 0.04119
#
# Epoch 00742: val_loss did not improve from 0.04119
#
# Epoch 00743: val_loss did not improve from 0.04119
#
# Epoch 00744: val_loss did not improve from 0.04119
#
# Epoch 00745: val_loss did not improve from 0.04119
#
# Epoch 00746: val_loss did not improve from 0.04119
#
# Epoch 00747: val_loss did not improve from 0.04119
#
# Epoch 00748: val_loss did not improve from 0.04119
#
# Epoch 00749: val_loss did not improve from 0.04119
#
# Epoch 00750: val_loss did not improve from 0.04119
#
# Epoch 00751: val_loss did not improve from 0.04119
#
# Epoch 00752: val_loss did not improve from 0.04119
#
# Epoch 00753: val_loss did not improve from 0.04119
#
# Epoch 00754: val_loss did not improve from 0.04119
#
# Epoch 00755: val_loss did not improve from 0.04119
#
# Epoch 00756: val_loss did not improve from 0.04119
#
# Epoch 00757: val_loss did not improve from 0.04119
#
# Epoch 00758: val_loss did not improve from 0.04119
#
# Epoch 00759: val_loss did not improve from 0.04119
#
# Epoch 00760: val_loss did not improve from 0.04119
#
# Epoch 00761: val_loss did not improve from 0.04119
#
# Epoch 00762: val_loss did not improve from 0.04119
#
# Epoch 00763: val_loss did not improve from 0.04119
#
# Epoch 00764: val_loss did not improve from 0.04119
#
# Epoch 00765: val_loss did not improve from 0.04119
#
# Epoch 00766: val_loss did not improve from 0.04119
#
# Epoch 00767: val_loss did not improve from 0.04119
#
# Epoch 00768: val_loss did not improve from 0.04119
#
# Epoch 00769: val_loss did not improve from 0.04119
#
# Epoch 00770: val_loss did not improve from 0.04119
#
# Epoch 00771: val_loss did not improve from 0.04119
#
# Epoch 00772: val_loss did not improve from 0.04119
#
# Epoch 00773: val_loss did not improve from 0.04119
#
# Epoch 00774: val_loss did not improve from 0.04119
#
# Epoch 00775: val_loss did not improve from 0.04119
#
# Epoch 00776: val_loss did not improve from 0.04119
#
# Epoch 00777: val_loss did not improve from 0.04119
#
# Epoch 00778: val_loss did not improve from 0.04119
#
# Epoch 00779: val_loss did not improve from 0.04119
#
# Epoch 00780: val_loss did not improve from 0.04119
#
# Epoch 00781: val_loss did not improve from 0.04119
#
# Epoch 00782: val_loss did not improve from 0.04119
#
# Epoch 00783: val_loss did not improve from 0.04119
#
# Epoch 00784: val_loss did not improve from 0.04119
#
# Epoch 00785: val_loss did not improve from 0.04119
#
# Epoch 00786: val_loss did not improve from 0.04119
#
# Epoch 00787: val_loss did not improve from 0.04119
#
# Epoch 00788: val_loss did not improve from 0.04119
#
# Epoch 00789: val_loss did not improve from 0.04119
#
# Epoch 00790: val_loss did not improve from 0.04119
#
# Epoch 00791: val_loss did not improve from 0.04119
#
# Epoch 00792: val_loss did not improve from 0.04119
#
# Epoch 00793: val_loss did not improve from 0.04119
#
# Epoch 00794: val_loss did not improve from 0.04119
#
# Epoch 00795: val_loss did not improve from 0.04119
#
# Epoch 00796: val_loss did not improve from 0.04119
#
# Epoch 00797: val_loss did not improve from 0.04119
#
# Epoch 00798: val_loss did not improve from 0.04119
#
# Epoch 00799: val_loss did not improve from 0.04119
#
# Epoch 00800: val_loss did not improve from 0.04119
#
# Epoch 00801: val_loss did not improve from 0.04119
#
# Epoch 00802: val_loss did not improve from 0.04119
#
# Epoch 00803: val_loss did not improve from 0.04119
#
# Epoch 00804: val_loss did not improve from 0.04119
#
# Epoch 00805: val_loss did not improve from 0.04119
#
# Epoch 00806: val_loss did not improve from 0.04119
#
# Epoch 00807: val_loss did not improve from 0.04119
#
# Epoch 00808: val_loss did not improve from 0.04119
#
# Epoch 00809: val_loss did not improve from 0.04119
#
# Epoch 00810: val_loss did not improve from 0.04119
#
# Epoch 00811: val_loss did not improve from 0.04119
#
# Epoch 00812: val_loss did not improve from 0.04119
#
# Epoch 00813: val_loss did not improve from 0.04119
#
# Epoch 00814: val_loss did not improve from 0.04119
#
# Epoch 00815: val_loss did not improve from 0.04119
#
# Epoch 00816: val_loss did not improve from 0.04119
#
# Epoch 00817: val_loss did not improve from 0.04119
#
# Epoch 00818: val_loss did not improve from 0.04119

# %%
from keras.models import load_model
del model
model = load_model('model4/763-0.0468.hdf5')
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-4081d290b07a> in <module>
#       1 from keras.models import load_model
#       2 del model
# ----> 3 model = load_model('model4/763-0.0468.hdf5')
#       4 print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     415     model = None
#     416     opened_new_file = not isinstance(filepath, h5py.Group)
# --> 417     f = h5dict(filepath, 'r')
#     418     try:
#     419         model = _deserialize_model(f, custom_objects, compile)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\io_utils.py in __init__(self, path, mode)
#     184             self._is_file = False
#     185         elif isinstance(path, str):
# --> 186             self.data = h5py.File(path, mode=mode)
#     187             self._is_file = True
#     188         elif isinstance(path, dict):
#
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     392                 fid = make_fid(name, mode, userblock_size,
#     393                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 394                                swmr=swmr)
#     395
#     396             if swmr_support:
#
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     168         if swmr and swmr_support:
#     169             flags |= h5f.ACC_SWMR_READ
# --> 170         fid = h5f.open(name, flags, fapl=fapl)
#     171     elif mode == 'r+':
#     172         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'model4/763-0.0468.hdf5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
